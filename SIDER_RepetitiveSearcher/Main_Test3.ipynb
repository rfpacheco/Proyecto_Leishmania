# %%
main_list2 = [
     [number] + row for number, row in enumerate(main_list, start=1)
]

# %%
for first, second in zip(*[iter(main_list2)] * 2):
    print("First:", first[0], first[11], first[12])
    print("\nSecond:", second[0], second[11], second[12], "\n")
# Out:
# First: 1 23938 24929
#
# Second: 2 23869 24807
#
# First: 3 75646 76645
#
# Second: 4 75666 76665
#
# First: 5 137265 138207
#
# Second: 6 137096 137974
#
# First: 7 205336 206286
#
# Second: 8 123006 124005
#
# First: 9 123038 124006
#
# Second: 10 205077 206071
#
# First: 11 55707 54709
#
# Second: 12 55776 54838
#
# First: 13 36117 35124
#
# Second: 14 36164 35226
#
# First: 15 130786 129838
#
# Second: 16 130855 129945
#
# First: 17 114285 113373
#
# Second: 18 114389 113390

# %%
plus_list = [x for x in main_list if "plus" in x[14]]

# %%
minus_list = [x for x in main_list if "minus" in x[14]]

# %%
plus_list2 = sorted(plus_list, key=lambda x: x[10], reverse=True)

# %%
len(plus_list2) == len(plus_list)
# Out:
# True

# %%
[x[10] for x in plus_list]
# Out:
# ['23938',
#  '23869',
#  '75646',
#  '75666',
#  '137265',
#  '137096',
#  '205336',
#  '123006',
#  '123038',
#  '205077']

# %%
[x[10] for x in plus_list2]
# Out:
# ['75666',
#  '75646',
#  '23938',
#  '23869',
#  '205336',
#  '205077',
#  '137265',
#  '137096',
#  '123038',
#  '123006']

# %%
plus_list3 = [[number] + row for number, row in enumerate(plus_list2, start=1)]

# %%
for first, second in zip(*[iter(plus_list3)] * 2):
    print("First:", first[0], first[11], first[12])
    print("\nSecond:", second[0], second[11], second[12], "\n")
# Out:
# First: 1 75666 76665
#
# Second: 2 75646 76645
#
# First: 3 23938 24929
#
# Second: 4 23869 24807
#
# First: 5 205336 206286
#
# Second: 6 205077 206071
#
# First: 7 137265 138207
#
# Second: 8 137096 137974
#
# First: 9 123038 124006
#
# Second: 10 123006 124005

# %%
test1 = [('75646', '76665', 'plus'), ('23869', '24929', 'plus'), ('205077', '206286', 'plus'), ('137096', '138207', 'plus'), ('123006', '124006', 'plus'), ('55776', '54709', 'minus'), ('36164', '35124', 'minus'), ('130855', '129838', 'minus'), ('114389', '113373', 'minus')]

# %%
[x for x in test1]
# Out:
# [('75646', '76665', 'plus'),
#  ('23869', '24929', 'plus'),
#  ('205077', '206286', 'plus'),
#  ('137096', '138207', 'plus'),
#  ('123006', '124006', 'plus'),
#  ('55776', '54709', 'minus'),
#  ('36164', '35124', 'minus'),
#  ('130855', '129838', 'minus'),
#  ('114389', '113373', 'minus')]

# %%
len(test1)
# Out:
# 9
